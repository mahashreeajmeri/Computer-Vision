# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import v2

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32,scale=True)]),  
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)]),
)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# rob mulla yt video

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import timm

import matplotlib.pyplot as plt # For data viz
import pandas as pd
import numpy as np
import sys
from tqdm.notebook import tqdm

print('System Version:', sys.version)
print('PyTorch version', torch.__version__)
print('Torchvision version', torchvision.__version__)
print('Numpy version', np.__version__)
print('Pandas version', pd.__version__)
# Out:
# System Version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# PyTorch version 2.13.0+cpu
# Torchvision version 0.28.0+cpu
# Numpy version 2.1.3
# Pandas version 2.2.3

# %%
class PlayingCardDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data= ImageFolder(data_dir, transform=transform)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return  self.data[idx]

    # property
    def classes(self):
        return self.data.classes

# %%
import pandas as pd

df = pd.read_parquet(
    "C:\\Users\\MAHASHREE AJMERI\\Downloads\\gzcd_volunteer_classifications_zoostyle.parquet"
)

print(df.shape)
print(df.columns.tolist())
# Out:
# (45226, 103)
# ['smooth-or-featured-cd_smooth', 'smooth-or-featured-cd_featured-or-disk', 'smooth-or-featured-cd_problem', 'how-rounded-cd_round', 'how-rounded-cd_in-between', 'how-rounded-cd_cigar-shaped', 'disk-edge-on-cd_yes', 'disk-edge-on-cd_no', 'edge-on-bulge-cd_rounded', 'edge-on-bulge-cd_boxy', 'edge-on-bulge-cd_none', 'bar-cd_strong', 'bar-cd_weak', 'bar-cd_no', 'has-spiral-arms-cd_yes', 'has-spiral-arms-cd_no', 'spiral-winding-cd_tight', 'spiral-winding-cd_medium', 'spiral-winding-cd_loose', 'spiral-arm-count-cd_1', 'spiral-arm-count-cd_2', 'spiral-arm-count-cd_3', 'spiral-arm-count-cd_4', 'spiral-arm-count-cd_more-than-4', 'spiral-arm-count-cd_cant-tell', 'bulge-size-cd_none', 'bulge-size-cd_small', 'bulge-size-cd_moderate', 'bulge-size-cd_large', 'bulge-size-cd_dominant', 'merging-cd_merger', 'merging-cd_major-disturbance', 'merging-cd_minor-disturbance', 'merging-cd_none', 'clumps-cd_yes', 'clumps-cd_no', 'problem-cd_star', 'problem-cd_artifact', 'problem-cd_zoom', 'artifact-cd_satellite', 'artifact-cd_scattered', 'artifact-cd_diffraction', 'artifact-cd_ray', 'artifact-cd_saturation', 'artifact-cd_other', 'smooth-or-featured-cd_total-votes', 'how-rounded-cd_total-votes', 'disk-edge-on-cd_total-votes', 'edge-on-bulge-cd_total-votes', 'bar-cd_total-votes', 'has-spiral-arms-cd_total-votes', 'spiral-winding-cd_total-votes', 'spiral-arm-count-cd_total-votes', 'bulge-size-cd_total-votes', 'merging-cd_total-votes', 'clumps-cd_total-votes', 'problem-cd_total-votes', 'artifact-cd_total-votes', 'smooth-or-featured-cd_smooth_fraction', 'smooth-or-featured-cd_featured-or-disk_fraction', 'smooth-or-featured-cd_problem_fraction', 'how-rounded-cd_round_fraction', 'how-rounded-cd_in-between_fraction', 'how-rounded-cd_cigar-shaped_fraction', 'disk-edge-on-cd_yes_fraction', 'disk-edge-on-cd_no_fraction', 'edge-on-bulge-cd_rounded_fraction', 'edge-on-bulge-cd_boxy_fraction', 'edge-on-bulge-cd_none_fraction', 'bar-cd_strong_fraction', 'bar-cd_weak_fraction', 'bar-cd_no_fraction', 'has-spiral-arms-cd_yes_fraction', 'has-spiral-arms-cd_no_fraction', 'spiral-winding-cd_tight_fraction', 'spiral-winding-cd_medium_fraction', 'spiral-winding-cd_loose_fraction', 'spiral-arm-count-cd_1_fraction', 'spiral-arm-count-cd_2_fraction', 'spiral-arm-count-cd_3_fraction', 'spiral-arm-count-cd_4_fraction', 'spiral-arm-count-cd_more-than-4_fraction', 'spiral-arm-count-cd_cant-tell_fraction', 'bulge-size-cd_none_fraction', 'bulge-size-cd_small_fraction', 'bulge-size-cd_moderate_fraction', 'bulge-size-cd_large_fraction', 'bulge-size-cd_dominant_fraction', 'merging-cd_merger_fraction', 'merging-cd_major-disturbance_fraction', 'merging-cd_minor-disturbance_fraction', 'merging-cd_none_fraction', 'clumps-cd_yes_fraction', 'clumps-cd_no_fraction', 'problem-cd_star_fraction', 'problem-cd_artifact_fraction', 'problem-cd_zoom_fraction', 'artifact-cd_satellite_fraction', 'artifact-cd_scattered_fraction', 'artifact-cd_diffraction_fraction', 'artifact-cd_ray_fraction', 'artifact-cd_saturation_fraction', 'artifact-cd_other_fraction']
